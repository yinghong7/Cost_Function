# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
import h5py
import keras.backend as K
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Activation
from keras import optimizers, layers, callbacks
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Productivity improvement (CB1,CB2,CB4,CB5,CB7)

# %%
x_1 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_train_scale.csv', 
                    delimiter = ',', usecols = (2,3,4,5,6), skip_header=1)
y_1 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_train_scale.csv', 
                   delimiter =',', usecols = (23,24,25,26,27,28,29), skip_header=1)
x_2 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_cv_scale.csv', 
                    delimiter = ',', usecols = (2,3,4,5,6), skip_header=1)
y_2 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_cv_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

# %%
y_whole = np.vstack ((y_1, y_2)).astype(np.float32)
x_whole = np.vstack ((x_1, x_2)).astype(np.float32)
x_traind = x_1
x_test = x_2
y_traind = y_1
y_test = y_2
x_train, x_cv, y_train, y_cv = train_test_split (x_1,y_1,test_size=0.13)

# %%
batch_size = 70
num_classes = 7

model = Sequential ()
model.add (Dense (units = 16, input_dim = 5))
model.add (layers.Activation ('tanh'))
model.add (Dense (units = 16))
model.add (layers.Activation ('tanh'))
model.add (Dense (units = 16))
#model.add (layers.Activation ('tanh'))
#model.add (Dense (units = 16))
model.add (Dense(num_classes, activation = 'tanh'))

#sgd = optimizer.SGD (lr=0.01, momentum = 0, decay =0, nestrov = False)
model.compile (loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])

History = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=60,
                    verbose=1, validation_data=(x_cv, y_cv))

print(model.evaluate (x_test, y_test, batch_size = 70, verbose =1))

#help (model.evaluate)
#this is the output units

y_pred_train = model.predict (x_train)
y_pred_cv = model.predict (x_cv)
y_pred_test = model.predict (x_test)
y_pred_whole = np.vstack ((y_pred_train, y_pred_cv, y_pred_test)).astype(np.float32)
# Out:
# Train on 67 samples, validate on 11 samples
# Epoch 1/60
# 67/67 [==============================] - ETA: 0s - loss: 3.0580 - binary_accuracy: 0.6333 - val_loss: 2.6774 - val_binary_accuracy: 0.6234
# Epoch 2/60
# 67/67 [==============================] - ETA: 0s - loss: 2.7990 - binary_accuracy: 0.6311 - val_loss: 2.6751 - val_binary_accuracy: 0.6234
# Epoch 3/60
# 67/67 [==============================] - ETA: 0s - loss: 2.7255 - binary_accuracy: 0.6311 - val_loss: 2.1724 - val_binary_accuracy: 0.6364
# Epoch 4/60
# 67/67 [==============================] - ETA: 0s - loss: 2.2828 - binary_accuracy: 0.6290 - val_loss: 2.1528 - val_binary_accuracy: 0.6364
# Epoch 5/60
# 67/67 [==============================] - ETA: 0s - loss: 2.2692 - binary_accuracy: 0.6333 - val_loss: 2.1426 - val_binary_accuracy: 0.6364
# Epoch 6/60
# 67/67 [==============================] - ETA: 0s - loss: 2.2609 - binary_accuracy: 0.6333 - val_loss: 2.1352 - val_binary_accuracy: 0.6364
# Epoch 7/60
# 67/67 [==============================] - ETA: 0s - loss: 2.2544 - binary_accuracy: 0.6397 - val_loss: 2.1293 - val_binary_accuracy: 0.6364
# Epoch 8/60
# 67/67 [==============================] - ETA: 0s - loss: 2.2095 - binary_accuracy: 0.6397 - val_loss: 1.8992 - val_binary_accuracy: 0.6364
# Epoch 9/60
# 67/67 [==============================] - ETA: 0s - loss: 1.9784 - binary_accuracy: 0.6119 - val_loss: 1.7282 - val_binary_accuracy: 0.6104
# Epoch 10/60
# 67/67 [==============================] - ETA: 0s - loss: 1.8116 - binary_accuracy: 0.6247 - val_loss: 1.7213 - val_binary_accuracy: 0.6234
# Epoch 11/60
# 67/67 [==============================] - ETA: 0s - loss: 1.8039 - binary_accuracy: 0.6247 - val_loss: 1.7159 - val_binary_accuracy: 0.6234
# Epoch 12/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7979 - binary_accuracy: 0.6226 - val_loss: 1.7116 - val_binary_accuracy: 0.6234
# Epoch 13/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7927 - binary_accuracy: 0.6247 - val_loss: 1.7080 - val_binary_accuracy: 0.6234
# Epoch 14/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7882 - binary_accuracy: 0.6247 - val_loss: 1.7048 - val_binary_accuracy: 0.6104
# Epoch 15/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7842 - binary_accuracy: 0.6247 - val_loss: 1.7020 - val_binary_accuracy: 0.6104
# Epoch 16/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7622 - binary_accuracy: 0.6247 - val_loss: 1.8970 - val_binary_accuracy: 0.5974
# Epoch 17/60
# 67/67 [==============================] - ETA: 0s - loss: 1.8412 - binary_accuracy: 0.6290 - val_loss: 1.8948 - val_binary_accuracy: 0.5974
# Epoch 18/60
# 67/67 [==============================] - ETA: 0s - loss: 1.8314 - binary_accuracy: 0.6375 - val_loss: 1.7510 - val_binary_accuracy: 0.5974
# Epoch 19/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7845 - binary_accuracy: 0.6397 - val_loss: 1.7017 - val_binary_accuracy: 0.6104
# Epoch 20/60
# 67/67 [==============================] - ETA: 0s - loss: 1.7033 - binary_accuracy: 0.6375 - val_loss: 1.6978 - val_binary_accuracy: 0.6104
# Epoch 21/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6972 - binary_accuracy: 0.6375 - val_loss: 1.6954 - val_binary_accuracy: 0.6234
# Epoch 22/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6938 - binary_accuracy: 0.6354 - val_loss: 1.6935 - val_binary_accuracy: 0.6234
# Epoch 23/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6910 - binary_accuracy: 0.6354 - val_loss: 1.6918 - val_binary_accuracy: 0.6234
# Epoch 24/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6651 - binary_accuracy: 0.6375 - val_loss: 1.6896 - val_binary_accuracy: 0.6234
# Epoch 25/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6558 - binary_accuracy: 0.6397 - val_loss: 1.6882 - val_binary_accuracy: 0.6234
# Epoch 26/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6535 - binary_accuracy: 0.6397 - val_loss: 1.6870 - val_binary_accuracy: 0.6234
# Epoch 27/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6514 - binary_accuracy: 0.6397 - val_loss: 1.6859 - val_binary_accuracy: 0.6234
# Epoch 28/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6495 - binary_accuracy: 0.6439 - val_loss: 1.6850 - val_binary_accuracy: 0.6234
# Epoch 29/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6478 - binary_accuracy: 0.6461 - val_loss: 1.6841 - val_binary_accuracy: 0.6234
# Epoch 30/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6461 - binary_accuracy: 0.6461 - val_loss: 1.6833 - val_binary_accuracy: 0.6364
# Epoch 31/60
# 67/67 [==============================] - ETA: 0s - loss: 1.6243 - binary_accuracy: 0.6439 - val_loss: 1.6822 - val_binary_accuracy: 0.6364
# Epoch 32/60
# 67/67 [==============================] - ETA: 0s - loss: 1.4830 - binary_accuracy: 0.6546 - val_loss: 1.5093 - val_binary_accuracy: 0.6104
# Epoch 33/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3526 - binary_accuracy: 0.6525 - val_loss: 1.5084 - val_binary_accuracy: 0.6104
# Epoch 34/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3172 - binary_accuracy: 0.6546 - val_loss: 1.5059 - val_binary_accuracy: 0.6104
# Epoch 35/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3122 - binary_accuracy: 0.6546 - val_loss: 1.5045 - val_binary_accuracy: 0.6104
# Epoch 36/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3092 - binary_accuracy: 0.6546 - val_loss: 1.5035 - val_binary_accuracy: 0.6104
# Epoch 37/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3068 - binary_accuracy: 0.6567 - val_loss: 1.5026 - val_binary_accuracy: 0.6104
# Epoch 38/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3047 - binary_accuracy: 0.6588 - val_loss: 1.5020 - val_binary_accuracy: 0.6104
# Epoch 39/60
# 67/67 [==============================] - ETA: 0s - loss: 1.3029 - binary_accuracy: 0.6631 - val_loss: 1.5014 - val_binary_accuracy: 0.6104
# Epoch 40/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2772 - binary_accuracy: 0.6652 - val_loss: 1.5020 - val_binary_accuracy: 0.5974
# Epoch 41/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2685 - binary_accuracy: 0.6610 - val_loss: 1.5016 - val_binary_accuracy: 0.5974
# Epoch 42/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2666 - binary_accuracy: 0.6610 - val_loss: 1.5014 - val_binary_accuracy: 0.5974
# Epoch 43/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2649 - binary_accuracy: 0.6610 - val_loss: 1.5011 - val_binary_accuracy: 0.5974
# Epoch 44/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2633 - binary_accuracy: 0.6631 - val_loss: 1.5009 - val_binary_accuracy: 0.5974
# Epoch 45/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2618 - binary_accuracy: 0.6695 - val_loss: 1.5008 - val_binary_accuracy: 0.5974
# Epoch 46/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2604 - binary_accuracy: 0.6738 - val_loss: 1.5007 - val_binary_accuracy: 0.5974
# Epoch 47/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2591 - binary_accuracy: 0.6716 - val_loss: 1.5006 - val_binary_accuracy: 0.5974
# Epoch 48/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2413 - binary_accuracy: 0.6780 - val_loss: 1.5846 - val_binary_accuracy: 0.5195
# Epoch 49/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2781 - binary_accuracy: 0.6226 - val_loss: 1.5820 - val_binary_accuracy: 0.5195
# Epoch 50/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2749 - binary_accuracy: 0.6269 - val_loss: 1.5798 - val_binary_accuracy: 0.5195
# Epoch 51/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2720 - binary_accuracy: 0.6269 - val_loss: 1.5778 - val_binary_accuracy: 0.5195
# Epoch 52/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2693 - binary_accuracy: 0.6247 - val_loss: 1.5761 - val_binary_accuracy: 0.5195
# Epoch 53/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2669 - binary_accuracy: 0.6247 - val_loss: 1.5745 - val_binary_accuracy: 0.5065
# Epoch 54/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2647 - binary_accuracy: 0.6226 - val_loss: 1.5731 - val_binary_accuracy: 0.5195
# Epoch 55/60
# 67/67 [==============================] - ETA: 0s - loss: 1.2433 - binary_accuracy: 0.6226 - val_loss: 1.7671 - val_binary_accuracy: 0.5195
# Epoch 56/60
# 67/67 [==============================] - ETA: 0s - loss: 1.0909 - binary_accuracy: 0.6226 - val_loss: 1.7700 - val_binary_accuracy: 0.5195
# Epoch 57/60
# 67/67 [==============================] - ETA: 0s - loss: 1.0826 - binary_accuracy: 0.6311 - val_loss: 1.7674 - val_binary_accuracy: 0.5195
# Epoch 58/60
# 67/67 [==============================] - ETA: 0s - loss: 1.0788 - binary_accuracy: 0.6354 - val_loss: 1.7659 - val_binary_accuracy: 0.5195
# Epoch 59/60
# 67/67 [==============================] - ETA: 0s - loss: 1.0760 - binary_accuracy: 0.6354 - val_loss: 1.7647 - val_binary_accuracy: 0.5325
# Epoch 60/60
# 67/67 [==============================] - ETA: 0s - loss: 1.0736 - binary_accuracy: 0.6397 - val_loss: 1.7637 - val_binary_accuracy: 0.5455
# 20/20 [==============================] - ETA: 0s
# [0.68408459424972534, 0.61428576707839966]

# %% [markdown]
# ### t(x) for labelling

# %%
#creating 100 random numbers
y_pred = y_pred_whole
f = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Jupyter/Keras/f_random.csv', 
                    delimiter = ',').reshape(100,1)
def t(x):
    return f.item (x)

def k (x):
    k = np.zeros ((98,7));
    i = 0;
    j = 0;
    for i in range (98):
        for j in range (7):
            if y_pred.item((i,j))<=t(x):
                np.put(k,[7*i+j],[1]);
    return k

g = np.zeros((98,1))
for x in range (100):
    m = np.sum(k(x), axis = 1).reshape(98,1);
    #print (m.shape)
    g = np.hstack((g,m));
g = np.delete(g,0,1)


i = 0
j = 0
m = np.zeros((98,100))
for i in range (98):
    min =100
    for j in range (100):
        if g.item ((i,j))<=min:
            min = g.item((i,j))
    for j in range (100):
        if g.item ((i,j))==min:
            np.put(m,[100*i+j],[1])
            
i = 0
j = 0
w = np.zeros((98,100))
for i in range (0,98):
    for j in range (0, 100):
        w_ = m.item((i,j))*t(j)
        np.put(w,[100*i+j],[w_])

        
cnt = np.count_nonzero(w, axis=1).reshape(98,1)
re_cnt = cnt[::-1]
w_total = np.sum(w, axis = 1).reshape(98,1)
w_avg = w_total/re_cnt
A = np.hstack([y_pred, np.ones((98,1))])
w1,w2,w3,w4,w5,w6,w7,b = np.linalg.lstsq(A,w_avg)[0]
print (w1,w2,w3,w4,w5,w6,w7,b)


def y_label (y_pred):
    
    I = y_pred.shape[0];
    J = y_pred.shape[1];
    
    x1_Y = y_pred [:,0].reshape(I,1);
    x2_Y = y_pred [:,1].reshape(I,1);
    x3_Y = y_pred [:,2].reshape(I,1);
    x4_Y = y_pred [:,3].reshape(I,1);
    x5_Y = y_pred [:,4].reshape(I,1);
    x6_Y = y_pred [:,5].reshape(I,1);
    x7_Y = y_pred [:,6].reshape(I,1);
    
    c_x = y_pred.reshape(I,J);
    y_thre = np.zeros((I,1));
    y_label = np.zeros((I,J));
    
    i = 0;
    j = 0;
    
    for i in range (I):
        x1 = x1_Y.item(i,0);
        x2 = x2_Y.item(i,0);
        x3 = x3_Y.item(i,0);
        x4 = x4_Y.item(i,0);
        x5 = x5_Y.item(i,0);
        x6 = x6_Y.item(i,0);
        x7 = x7_Y.item(i,0);
        y_tx = w1*x1+w2*x2+w3*x3+w4*x4+w5*x5+w6*x6+w7*x7+b;
        np.put (y_thre, [i], [y_tx]);
        
    for i in range (I):
        for j in range (J):
            threshold = y_thre.item(i,0);
            if c_x.item(i,j) >= threshold:
                np.put(y_label, [J*i+j], [1])
    
    return (y_label)


y_train_label = y_label(y_pred_train)
y_cv_label = y_label(y_pred_cv)
y_test_label = y_label(y_pred_test)
y_t_label = np.vstack((y_train_label,y_cv_label))
y_t = np.vstack((y_train,y_cv))

from sklearn.metrics import hamming_loss
from sklearn.metrics import coverage_error
print('hamming_loss_train',hamming_loss(y_train, y_train_label))
print('hamming_loss_cv',hamming_loss(y_cv, y_cv_label))
print('hamming_loss_test',hamming_loss(y_test, y_test_label))
print('hamming_loss_traindataset',hamming_loss(y_t, y_t_label))
# Out:
# [ 1.83511418] [ 0.82210386] [ 0.74227144] [ 1.44485445] [-0.77729039] [ 1.59851172] [ 0.35063673] [-1.05591537]
# hamming_loss_train 0.373134328358209
# hamming_loss_cv 0.44155844155844154
# hamming_loss_test 0.35714285714285715
# hamming_loss_traindataset 0.38278388278388276

# %%
#save model to json, weights to HDF5
model_json = model.to_json ()
with open ('model_app_productivity_improve_a.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('model_app_productivity_improve_a.h5')
print ('Saved model to disk')
# Out:
# Saved model to disk

# %%
#load json and create model
json_file = open('model_app_productivity_improve_a.json', 'r')
loaded_model_json = json_file.read ()
json_file.close ()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights('model_app_productivity_improve_a.h5')

# %%
x_test = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a1_cv_scale.csv', 
                    delimiter = ',', usecols = (2,3,4,5,6), skip_header=1)
y_test = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a1_cv_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

loaded_model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])
print(loaded_model.evaluate (x_test, y_test, batch_size = 50))
y_pred_test = loaded_model.predict (x_test)

x1 = y_pred_test [:,0].reshape(14,1);
x2 = y_pred_test [:,1].reshape(14,1);
x3 = y_pred_test [:,2].reshape(14,1);
x4 = y_pred_test [:,3].reshape(14,1);
x5 = y_pred_test [:,4].reshape(14,1);
x6 = y_pred_test [:,5].reshape(14,1);
x7 = y_pred_test [:,6].reshape(14,1);

i = 0;
label_cf = np.zeros((14,1));
for i in range (14):
    y_tx = 4.36*x1+0.21*x2-0.21*x3-6.29*x4-5.66*x5-1.43*x6+5.93*x7-0.62;
    np.put(label_cf, [i], [y_tx]);
    label = np.hstack((y_pred_test, label_cf)).reshape((14,8))
    
    
i = 0;
j = 0;
cf = np.zeros((14,7))
for i in range (14):
    for j in range (7):
        cf_1 = y_pred_test.item((i,j))-label_cf.item((i,0));
        cf_2 = 10*cf_1;
        np.put(cf, [7*i+j], [cf_2]);
        
np.savetxt('y_cost_APPproduct_improve.csv', cf, delimiter=',')
# Out:
# 14/14 [==============================] - ETA: 0s
# [68.573471069335938, 0.55102044343948364]

# %%
x_whole = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_whole_scale.csv', 
                    delimiter = ',', usecols = (2,3,4,5,6), skip_header=1)
y_whole = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_whole_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)
loaded_model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])
print(loaded_model.evaluate (x_whole, y_whole, batch_size = 50))
y_pred_test = loaded_model.predict (x_whole)

x1 = y_pred_test [:,0].reshape(98,1);
x2 = y_pred_test [:,1].reshape(98,1);
x3 = y_pred_test [:,2].reshape(98,1);
x4 = y_pred_test [:,3].reshape(98,1);
x5 = y_pred_test [:,4].reshape(98,1);
x6 = y_pred_test [:,5].reshape(98,1);
x7 = y_pred_test [:,6].reshape(98,1);

i = 0;
label_cf = np.zeros((98,1));
for i in range (98):
    y_tx = 4.36*x1+0.21*x2-0.21*x3-6.29*x4-5.66*x5-1.43*x6+5.93*x7-0.62;
    np.put(label_cf, [i], [y_tx]);
    label = np.hstack((y_pred_test, label_cf)).reshape((98,8))
    
    
i = 0;
j = 0;
cf = np.zeros((98,7))
for i in range (98):
    for j in range (7):
        cf_1 = y_pred_test.item((i,j))-label_cf.item((i,0));
        cf_2 = 10*cf_1;
        np.put(cf, [7*i+j], [cf_2]);
        
np.savetxt('APPproduct_improve_total.csv', cf, delimiter=',')
# Out:
# 98/98 [==============================] - ETA: 0s
# [1.0699933621348168, 0.62390671335921]
