# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
import h5py
import keras.backend as K
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Activation
from keras import optimizers, layers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.metrics import hamming_loss, coverage_error
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Installation costs(IM6, CB8, OS3)

# %%
x_1 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_train_scale.csv', 
                    delimiter = ',', usecols = (15,16,17,18), skip_header=1)
y_1 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_train_scale.csv', 
                   delimiter =',', usecols = (23,24,25,26,27,28,29), skip_header=1)
x_2 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_cv_scale.csv', 
                    delimiter = ',', usecols = (15,16,17,18), skip_header=1)
y_2 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_cv_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

# %%
y_whole = np.vstack ((y_1, y_2)).astype(np.float32)
x_whole = np.vstack ((x_1, x_2)).astype(np.float32)
x_traind = x_1
x_test = x_2
y_traind = y_1
y_test = y_2
x_train, x_cv, y_train, y_cv = train_test_split (x_1,y_1,test_size=0.13)

# %%
batch_size = 50
num_classes = 7

model = Sequential ()
model.add (Dense (units = 36, input_dim = 4))
model.add (layers.Activation ('tanh'))
model.add (Dense (units = 36))
model.add (layers.Activation ('tanh'))
model.add (Dense (units = 36))
#model.add (layers.Activation ('tanh'))
#model.add (Dense (units = 25))
model.add (Dense(num_classes, activation = 'tanh'))

#sgd = optimizer.SGD (lr=0.01, momentum = 0, decay =0, nestrov = False)
model.compile (loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])

History = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=70,
                    verbose=1, validation_data=(x_cv, y_cv))
#print (model.summary())
print(model.evaluate (x_test, y_test, batch_size = 50, verbose =1))

#help (model.evaluate)
#this is the output units

y_pred_train = model.predict (x_train)
y_pred_cv = model.predict (x_cv)
y_pred_test = model.predict (x_test)
y_pred_whole = np.vstack ((y_pred_train, y_pred_cv, y_pred_test)).astype(np.float32)
# Out:
# Train on 67 samples, validate on 11 samples
# Epoch 1/70
# 67/67 [==============================] - ETA: 0s - loss: 3.0253 - binary_accuracy: 0.5928 - val_loss: 2.5086 - val_binary_accuracy: 0.6883
# Epoch 2/70
# 67/67 [==============================] - ETA: 0s - loss: 2.9707 - binary_accuracy: 0.5949 - val_loss: 2.3701 - val_binary_accuracy: 0.6753
# Epoch 3/70
# 67/67 [==============================] - ETA: 0s - loss: 2.7814 - binary_accuracy: 0.5544 - val_loss: 2.3555 - val_binary_accuracy: 0.6883
# Epoch 4/70
# 67/67 [==============================] - ETA: 0s - loss: 2.6503 - binary_accuracy: 0.5544 - val_loss: 2.2132 - val_binary_accuracy: 0.6883
# Epoch 5/70
# 67/67 [==============================] - ETA: 0s - loss: 2.5214 - binary_accuracy: 0.5586 - val_loss: 2.3397 - val_binary_accuracy: 0.7013
# Epoch 6/70
# 67/67 [==============================] - ETA: 0s - loss: 2.3954 - binary_accuracy: 0.5650 - val_loss: 2.3397 - val_binary_accuracy: 0.6883
# Epoch 7/70
# 67/67 [==============================] - ETA: 0s - loss: 2.2239 - binary_accuracy: 0.5757 - val_loss: 2.1486 - val_binary_accuracy: 0.6753
# Epoch 8/70
# 67/67 [==============================] - ETA: 0s - loss: 2.0961 - binary_accuracy: 0.5800 - val_loss: 2.1282 - val_binary_accuracy: 0.6753
# Epoch 9/70
# 67/67 [==============================] - ETA: 0s - loss: 2.0204 - binary_accuracy: 0.6034 - val_loss: 1.9807 - val_binary_accuracy: 0.6623
# Epoch 10/70
# 67/67 [==============================] - ETA: 0s - loss: 2.0102 - binary_accuracy: 0.6034 - val_loss: 1.9602 - val_binary_accuracy: 0.6623
# Epoch 11/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9987 - binary_accuracy: 0.6098 - val_loss: 1.9539 - val_binary_accuracy: 0.6623
# Epoch 12/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9925 - binary_accuracy: 0.6141 - val_loss: 1.8034 - val_binary_accuracy: 0.6623
# Epoch 13/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9872 - binary_accuracy: 0.6226 - val_loss: 1.7947 - val_binary_accuracy: 0.6623
# Epoch 14/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9817 - binary_accuracy: 0.6290 - val_loss: 1.8013 - val_binary_accuracy: 0.6623
# Epoch 15/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9770 - binary_accuracy: 0.6354 - val_loss: 1.8167 - val_binary_accuracy: 0.6494
# Epoch 16/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9730 - binary_accuracy: 0.6397 - val_loss: 1.8311 - val_binary_accuracy: 0.6494
# Epoch 17/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9693 - binary_accuracy: 0.6461 - val_loss: 1.9726 - val_binary_accuracy: 0.6494
# Epoch 18/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9661 - binary_accuracy: 0.6503 - val_loss: 1.9807 - val_binary_accuracy: 0.6494
# Epoch 19/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9633 - binary_accuracy: 0.6503 - val_loss: 1.9812 - val_binary_accuracy: 0.6494
# Epoch 20/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9606 - binary_accuracy: 0.6503 - val_loss: 1.9868 - val_binary_accuracy: 0.6494
# Epoch 21/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9583 - binary_accuracy: 0.6503 - val_loss: 1.9871 - val_binary_accuracy: 0.6494
# Epoch 22/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9566 - binary_accuracy: 0.6567 - val_loss: 1.9848 - val_binary_accuracy: 0.6494
# Epoch 23/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9536 - binary_accuracy: 0.6588 - val_loss: 1.9905 - val_binary_accuracy: 0.6494
# Epoch 24/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9522 - binary_accuracy: 0.6567 - val_loss: 1.9945 - val_binary_accuracy: 0.6494
# Epoch 25/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9293 - binary_accuracy: 0.6674 - val_loss: 1.8499 - val_binary_accuracy: 0.6104
# Epoch 26/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9157 - binary_accuracy: 0.6716 - val_loss: 2.0099 - val_binary_accuracy: 0.6104
# Epoch 27/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9144 - binary_accuracy: 0.6716 - val_loss: 2.0096 - val_binary_accuracy: 0.6104
# Epoch 28/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9132 - binary_accuracy: 0.6652 - val_loss: 2.0105 - val_binary_accuracy: 0.6104
# Epoch 29/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9117 - binary_accuracy: 0.6674 - val_loss: 2.0144 - val_binary_accuracy: 0.6104
# Epoch 30/70
# 67/67 [==============================] - ETA: 0s - loss: 1.9109 - binary_accuracy: 0.6716 - val_loss: 2.0154 - val_binary_accuracy: 0.6104
# Epoch 31/70
# 67/67 [==============================] - ETA: 0s - loss: 1.8902 - binary_accuracy: 0.6738 - val_loss: 1.6892 - val_binary_accuracy: 0.5714
# Epoch 32/70
# 67/67 [==============================] - ETA: 0s - loss: 1.7379 - binary_accuracy: 0.6610 - val_loss: 1.8272 - val_binary_accuracy: 0.5714
# Epoch 33/70
# 67/67 [==============================] - ETA: 0s - loss: 1.6827 - binary_accuracy: 0.6631 - val_loss: 1.8264 - val_binary_accuracy: 0.5844
# Epoch 34/70
# 67/67 [==============================] - ETA: 0s - loss: 1.6219 - binary_accuracy: 0.6652 - val_loss: 1.8178 - val_binary_accuracy: 0.5714
# Epoch 35/70
# 67/67 [==============================] - ETA: 0s - loss: 1.6142 - binary_accuracy: 0.6674 - val_loss: 1.8181 - val_binary_accuracy: 0.5844
# Epoch 36/70
# 67/67 [==============================] - ETA: 0s - loss: 1.6088 - binary_accuracy: 0.6674 - val_loss: 1.8200 - val_binary_accuracy: 0.5844
# Epoch 37/70
# 67/67 [==============================] - ETA: 0s - loss: 1.6068 - binary_accuracy: 0.6759 - val_loss: 1.8215 - val_binary_accuracy: 0.5974
# Epoch 38/70
# 67/67 [==============================] - ETA: 0s - loss: 1.6050 - binary_accuracy: 0.6716 - val_loss: 1.8214 - val_binary_accuracy: 0.5974
# Epoch 39/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5817 - binary_accuracy: 0.6759 - val_loss: 1.8232 - val_binary_accuracy: 0.5974
# Epoch 40/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5716 - binary_accuracy: 0.6652 - val_loss: 1.8247 - val_binary_accuracy: 0.5974
# Epoch 41/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5708 - binary_accuracy: 0.6716 - val_loss: 1.8244 - val_binary_accuracy: 0.5974
# Epoch 42/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5697 - binary_accuracy: 0.6652 - val_loss: 1.8312 - val_binary_accuracy: 0.5974
# Epoch 43/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5689 - binary_accuracy: 0.6759 - val_loss: 1.8324 - val_binary_accuracy: 0.5974
# Epoch 44/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5678 - binary_accuracy: 0.6844 - val_loss: 1.8397 - val_binary_accuracy: 0.5974
# Epoch 45/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5667 - binary_accuracy: 0.6844 - val_loss: 1.8445 - val_binary_accuracy: 0.5974
# Epoch 46/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5659 - binary_accuracy: 0.6780 - val_loss: 1.8511 - val_binary_accuracy: 0.5974
# Epoch 47/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5656 - binary_accuracy: 0.6759 - val_loss: 1.8474 - val_binary_accuracy: 0.5844
# Epoch 48/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5647 - binary_accuracy: 0.6844 - val_loss: 1.8505 - val_binary_accuracy: 0.5844
# Epoch 49/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5638 - binary_accuracy: 0.6887 - val_loss: 1.8508 - val_binary_accuracy: 0.6104
# Epoch 50/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5633 - binary_accuracy: 0.6908 - val_loss: 1.8587 - val_binary_accuracy: 0.6104
# Epoch 51/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5627 - binary_accuracy: 0.6930 - val_loss: 1.8550 - val_binary_accuracy: 0.6104
# Epoch 52/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5621 - binary_accuracy: 0.6908 - val_loss: 1.8708 - val_binary_accuracy: 0.6104
# Epoch 53/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5615 - binary_accuracy: 0.6951 - val_loss: 1.8760 - val_binary_accuracy: 0.6104
# Epoch 54/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5609 - binary_accuracy: 0.6887 - val_loss: 2.0283 - val_binary_accuracy: 0.6104
# Epoch 55/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5605 - binary_accuracy: 0.6844 - val_loss: 2.0213 - val_binary_accuracy: 0.6104
# Epoch 56/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5599 - binary_accuracy: 0.6887 - val_loss: 2.0261 - val_binary_accuracy: 0.6104
# Epoch 57/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5595 - binary_accuracy: 0.6866 - val_loss: 2.0231 - val_binary_accuracy: 0.6104
# Epoch 58/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5592 - binary_accuracy: 0.6866 - val_loss: 2.0298 - val_binary_accuracy: 0.6104
# Epoch 59/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5587 - binary_accuracy: 0.6908 - val_loss: 2.0380 - val_binary_accuracy: 0.6104
# Epoch 60/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5583 - binary_accuracy: 0.6908 - val_loss: 2.0448 - val_binary_accuracy: 0.6104
# Epoch 61/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5576 - binary_accuracy: 0.6866 - val_loss: 2.0586 - val_binary_accuracy: 0.6104
# Epoch 62/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5576 - binary_accuracy: 0.6844 - val_loss: 2.1913 - val_binary_accuracy: 0.6104
# Epoch 63/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5568 - binary_accuracy: 0.6887 - val_loss: 2.1959 - val_binary_accuracy: 0.6104
# Epoch 64/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5568 - binary_accuracy: 0.6823 - val_loss: 2.1759 - val_binary_accuracy: 0.6104
# Epoch 65/70
# 67/67 [==============================] - ETA: 0s - loss: 1.7356 - binary_accuracy: 0.685 - ETA: 0s - loss: 1.5563 - binary_accuracy: 0.6866 - val_loss: 2.1752 - val_binary_accuracy: 0.6104
# Epoch 66/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5557 - binary_accuracy: 0.6951 - val_loss: 2.1780 - val_binary_accuracy: 0.6104
# Epoch 67/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5556 - binary_accuracy: 0.6951 - val_loss: 2.1767 - val_binary_accuracy: 0.6104
# Epoch 68/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5551 - binary_accuracy: 0.6951 - val_loss: 2.1727 - val_binary_accuracy: 0.6104
# Epoch 69/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5546 - binary_accuracy: 0.6930 - val_loss: 2.1737 - val_binary_accuracy: 0.6104
# Epoch 70/70
# 67/67 [==============================] - ETA: 0s - loss: 1.5543 - binary_accuracy: 0.6951 - val_loss: 2.1796 - val_binary_accuracy: 0.6104
# 20/20 [==============================] - ETA: 0s
# [1.057042121887207, 0.74285715818405151]

# %%
#creating 100 random numbers
y_pred = y_pred_whole
f = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Jupyter/Keras/f_random.csv', 
                    delimiter = ',').reshape(100,1)
def t(x):
    return f.item (x)

def k (x):
    k = np.zeros ((98,7));
    i = 0;
    j = 0;
    for i in range (98):
        for j in range (7):
            if y_pred.item((i,j))<=t(x):
                np.put(k,[7*i+j],[1]);
    return k

g = np.zeros((98,1))
for x in range (100):
    m = np.sum(k(x), axis = 1).reshape(98,1);
    #print (m.shape)
    g = np.hstack((g,m));
g = np.delete(g,0,1)


i = 0
j = 0
m = np.zeros((98,100))
for i in range (98):
    min =100
    for j in range (100):
        if g.item ((i,j))<=min:
            min = g.item((i,j))
    for j in range (100):
        if g.item ((i,j))==min:
            np.put(m,[100*i+j],[1])
            
i = 0
j = 0
w = np.zeros((98,100))
for i in range (0,98):
    for j in range (0, 100):
        w_ = m.item((i,j))*t(j)
        np.put(w,[100*i+j],[w_])

        
cnt = np.count_nonzero(w, axis=1).reshape(98,1)
re_cnt = cnt[::-1]
w_total = np.sum(w, axis = 1).reshape(98,1)
w_avg = w_total/re_cnt
A = np.hstack([y_pred, np.ones((98,1))])
w1,w2,w3,w4,w5,w6,w7,b = np.linalg.lstsq(A,w_avg)[0]
print (w1,w2,w3,w4,w5,w6,w7,b)


def y_label (y_pred):
    
    I = y_pred.shape[0];
    J = y_pred.shape[1];
    
    x1_Y = y_pred [:,0].reshape(I,1);
    x2_Y = y_pred [:,1].reshape(I,1);
    x3_Y = y_pred [:,2].reshape(I,1);
    x4_Y = y_pred [:,3].reshape(I,1);
    x5_Y = y_pred [:,4].reshape(I,1);
    x6_Y = y_pred [:,5].reshape(I,1);
    x7_Y = y_pred [:,6].reshape(I,1);
    
    c_x = y_pred.reshape(I,J);
    y_thre = np.zeros((I,1));
    y_label = np.zeros((I,J));
    
    i = 0;
    j = 0;
    
    for i in range (I):
        x1 = x1_Y.item(i,0);
        x2 = x2_Y.item(i,0);
        x3 = x3_Y.item(i,0);
        x4 = x4_Y.item(i,0);
        x5 = x5_Y.item(i,0);
        x6 = x6_Y.item(i,0);
        x7 = x7_Y.item(i,0);
        y_tx = w1*x1+w2*x2+w3*x3+w4*x4+w5*x5+w6*x6+w7*x7+b;
        np.put (y_thre, [i], [y_tx]);
        
    for i in range (I):
        for j in range (J):
            threshold = y_thre.item(i,0);
            if c_x.item(i,j) >= threshold:
                np.put(y_label, [J*i+j], [1])
    
    return (y_label)


y_train_label = y_label(y_pred_train)
y_cv_label = y_label(y_pred_cv)
y_test_label = y_label(y_pred_test)
y_t_label = np.vstack((y_train_label,y_cv_label))
y_t = np.vstack((y_train,y_cv))

from sklearn.metrics import hamming_loss
from sklearn.metrics import coverage_error
print('hamming_loss_train',hamming_loss(y_train, y_train_label))
print('hamming_loss_cv',hamming_loss(y_cv, y_cv_label))
print('hamming_loss_test',hamming_loss(y_test, y_test_label))
print('hamming_loss_traindataset',hamming_loss(y_t, y_t_label))
# Out:
# [ 1.61357021] [ 0.29433134] [-0.92956452] [ 0.2888547] [ 0.04782259] [-0.01717986] [ 1.06324424] [-1.08717527]
# hamming_loss_train 0.3795309168443497
# hamming_loss_cv 0.5584415584415584
# hamming_loss_test 0.3
# hamming_loss_traindataset 0.40476190476190477

# %%
#save model to json, weights to HDF5
model_json = model.to_json ()
with open ('model_app_train_cost_a.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('model_app_train_cost_a.h5')
print ('Saved model to disk')
# Out:
# Saved model to disk

# %%
#load json and create model
json_file = open('model_app_train_cost_a.json', 'r')
loaded_model_json = json_file.read ()
json_file.close ()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights('model_app_train_cost_a.h5')

# %%
x_test = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a1_cv_scale.csv', 
                    delimiter = ',', usecols = (15,16,17,18), skip_header=1)
y_test = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a1_cv_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

loaded_model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])
print(loaded_model.evaluate (x_test, y_test, batch_size = 50))
y_pred_test = loaded_model.predict (x_test)

x1 = y_pred_test [:,0].reshape(14,1);
x2 = y_pred_test [:,1].reshape(14,1);
x3 = y_pred_test [:,2].reshape(14,1);
x4 = y_pred_test [:,3].reshape(14,1);
x5 = y_pred_test [:,4].reshape(14,1);
x6 = y_pred_test [:,5].reshape(14,1);
x7 = y_pred_test [:,6].reshape(14,1);

i = 0;
label_cf = np.zeros((14,1));
for i in range (14):
    y_tx = -0.78*x1-0.18*x2-0.33*x3-0.27*x4-0.57*x5-0.12*x6-0.25*x7+0.88;
    np.put(label_cf, [i], [y_tx]);
    label = np.hstack((y_pred_test, label_cf)).reshape((14,8))
    
    
i = 0;
j = 0;
cf = np.zeros((14,7))
for i in range (14):
    for j in range (7):
        cf_1 = y_pred_test.item((i,j))-label_cf.item((i,0));
        cf_2 = 10*cf_1;
        np.put(cf, [7*i+j], [cf_2]);
        
np.savetxt('y_cost_APPtrain_cost.csv', cf, delimiter=',')
# Out:
# 14/14 [==============================] - ETA: 0s
# [46.033985137939453, 0.65306121110916138]

# %%
#a_whole_scale
x_whole = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_whole_scale.csv', 
                    delimiter = ',', usecols = (15,16,17,18), skip_header=1)
y_whole = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_whole_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)
loaded_model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])
print(loaded_model.evaluate (x_whole, y_whole, batch_size = 50))
y_pred_test = loaded_model.predict (x_whole)

x1 = y_pred_test [:,0].reshape(98,1);
x2 = y_pred_test [:,1].reshape(98,1);
x3 = y_pred_test [:,2].reshape(98,1);
x4 = y_pred_test [:,3].reshape(98,1);
x5 = y_pred_test [:,4].reshape(98,1);
x6 = y_pred_test [:,5].reshape(98,1);
x7 = y_pred_test [:,6].reshape(98,1);

i = 0;
label_cf = np.zeros((98,1));
for i in range (98):
    y_tx = -0.78*x1-0.18*x2-0.33*x3-0.27*x4-0.57*x5-0.12*x6-0.25*x7+0.88;
    np.put(label_cf, [i], [y_tx]);
    label = np.hstack((y_pred_test, label_cf)).reshape((98,8))
    
    
i = 0;
j = 0;
cf = np.zeros((98,7))
for i in range (98):
    for j in range (7):
        cf_1 = y_pred_test.item((i,j))-label_cf.item((i,0));
        cf_2 = 10*cf_1;
        np.put(cf, [7*i+j], [cf_2]);
        
np.savetxt('APPtrain_cost_total.csv', cf, delimiter=',')
# Out:
# 98/98 [==============================] - ETA: 0s
# [1.5226154132765166, 0.69679305261495161]
