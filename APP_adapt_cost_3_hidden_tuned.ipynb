# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
import h5py
import keras.backend as K
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Activation
from keras import optimizers, layers, callbacks
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Adaptation cost (CB9,CB10,CB11,CB12)

# %%
x_1 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_train_scale.csv', 
                    delimiter = ',', usecols = (19,20,21,22), skip_header=1)
y_1 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_train_scale.csv', 
                   delimiter =',', usecols = (23,24,25,26,27,28,29), skip_header=1)
x_2 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_cv_scale.csv', 
                    delimiter = ',', usecols = (19,20,21,22), skip_header=1)
y_2 = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_cv_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

# %%
y_whole = np.vstack ((y_1, y_2)).astype(np.float32)
x_whole = np.vstack ((x_1, x_2)).astype(np.float32)
x_traind = x_1
x_test = x_2
y_traind = y_1
y_test = y_2
x_train, x_cv, y_train, y_cv = train_test_split (x_1,y_1,test_size=0.13)

# %%
#batch_size = 70
num_classes = 7

model = Sequential ()
model.add (Dense (units = 30, input_dim = 4))
model.add (layers.Activation ('tanh'))
model.add (Dense (units = 30))
model.add (layers.Activation ('tanh'))
model.add (Dense (units = 30))
#model.add (layers.Activation ('tanh'))
#model.add (Dense (units = 16))
model.add (Dense(num_classes, activation = 'tanh'))

#sgd = optimizer.SGD (lr=0.01, momentum = 0, decay =0, nestrov = False)
model.compile (loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])

History = model.fit(x_train, y_train,
                    batch_size=70,
                    epochs=50,
                    verbose=1, validation_data=(x_cv, y_cv))

print(model.evaluate (x_test, y_test, batch_size = 70, verbose =1))

#help (model.evaluate)
#this is the output units

y_pred_train = model.predict (x_train)
y_pred_cv = model.predict (x_cv)
y_pred_test = model.predict (x_test)
y_pred_whole = np.vstack ((y_pred_train, y_pred_cv, y_pred_test)).astype(np.float32)
# Out:
# Train on 67 samples, validate on 11 samples
# Epoch 1/50
# 67/67 [==============================] - ETA: 0s - loss: 2.7360 - binary_accuracy: 0.6098 - val_loss: 2.6929 - val_binary_accuracy: 0.5974
# Epoch 2/50
# 67/67 [==============================] - ETA: 0s - loss: 2.6734 - binary_accuracy: 0.6077 - val_loss: 2.6894 - val_binary_accuracy: 0.5974
# Epoch 3/50
# 67/67 [==============================] - ETA: 0s - loss: 2.6611 - binary_accuracy: 0.6077 - val_loss: 2.6843 - val_binary_accuracy: 0.5974
# Epoch 4/50
# 67/67 [==============================] - ETA: 0s - loss: 2.6102 - binary_accuracy: 0.6141 - val_loss: 2.5205 - val_binary_accuracy: 0.5974
# Epoch 5/50
# 67/67 [==============================] - ETA: 0s - loss: 2.5292 - binary_accuracy: 0.6119 - val_loss: 2.5065 - val_binary_accuracy: 0.5974
# Epoch 6/50
# 67/67 [==============================] - ETA: 0s - loss: 2.4961 - binary_accuracy: 0.6098 - val_loss: 2.3514 - val_binary_accuracy: 0.5974
# Epoch 7/50
# 67/67 [==============================] - ETA: 0s - loss: 2.4635 - binary_accuracy: 0.6119 - val_loss: 2.1883 - val_binary_accuracy: 0.5974
# Epoch 8/50
# 67/67 [==============================] - ETA: 0s - loss: 2.4543 - binary_accuracy: 0.6119 - val_loss: 2.1727 - val_binary_accuracy: 0.5844
# Epoch 9/50
# 67/67 [==============================] - ETA: 0s - loss: 2.4507 - binary_accuracy: 0.6077 - val_loss: 2.1622 - val_binary_accuracy: 0.5844
# Epoch 10/50
# 67/67 [==============================] - ETA: 0s - loss: 2.4260 - binary_accuracy: 0.6077 - val_loss: 2.1527 - val_binary_accuracy: 0.5974
# Epoch 11/50
# 67/67 [==============================] - ETA: 0s - loss: 2.3048 - binary_accuracy: 0.6055 - val_loss: 2.0513 - val_binary_accuracy: 0.6104
# Epoch 12/50
# 67/67 [==============================] - ETA: 0s - loss: 2.2939 - binary_accuracy: 0.6055 - val_loss: 1.9868 - val_binary_accuracy: 0.6104
# Epoch 13/50
# 67/67 [==============================] - ETA: 0s - loss: 2.2732 - binary_accuracy: 0.6055 - val_loss: 2.1236 - val_binary_accuracy: 0.5974
# Epoch 14/50
# 67/67 [==============================] - ETA: 0s - loss: 2.1782 - binary_accuracy: 0.6013 - val_loss: 1.9609 - val_binary_accuracy: 0.5974
# Epoch 15/50
# 67/67 [==============================] - ETA: 0s - loss: 2.1718 - binary_accuracy: 0.6013 - val_loss: 1.9499 - val_binary_accuracy: 0.5974
# Epoch 16/50
# 67/67 [==============================] - ETA: 0s - loss: 2.1682 - binary_accuracy: 0.6013 - val_loss: 1.9426 - val_binary_accuracy: 0.5974
# Epoch 17/50
# 67/67 [==============================] - ETA: 0s - loss: 2.1653 - binary_accuracy: 0.6034 - val_loss: 1.9371 - val_binary_accuracy: 0.5974
# Epoch 18/50
# 67/67 [==============================] - ETA: 0s - loss: 2.1627 - binary_accuracy: 0.6034 - val_loss: 1.9326 - val_binary_accuracy: 0.5974
# Epoch 19/50
# 67/67 [==============================] - ETA: 0s - loss: 2.1415 - binary_accuracy: 0.6055 - val_loss: 1.6938 - val_binary_accuracy: 0.5844
# Epoch 20/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0783 - binary_accuracy: 0.5991 - val_loss: 1.6953 - val_binary_accuracy: 0.5844
# Epoch 21/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0736 - binary_accuracy: 0.5991 - val_loss: 1.6946 - val_binary_accuracy: 0.5844
# Epoch 22/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0488 - binary_accuracy: 0.5991 - val_loss: 1.6923 - val_binary_accuracy: 0.5844
# Epoch 23/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0095 - binary_accuracy: 0.5991 - val_loss: 1.6920 - val_binary_accuracy: 0.5844
# Epoch 24/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0070 - binary_accuracy: 0.6034 - val_loss: 1.6915 - val_binary_accuracy: 0.5844
# Epoch 25/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0050 - binary_accuracy: 0.6055 - val_loss: 1.6909 - val_binary_accuracy: 0.5844
# Epoch 26/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0032 - binary_accuracy: 0.6098 - val_loss: 1.6903 - val_binary_accuracy: 0.5844
# Epoch 27/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0015 - binary_accuracy: 0.6098 - val_loss: 1.6897 - val_binary_accuracy: 0.5844
# Epoch 28/50
# 67/67 [==============================] - ETA: 0s - loss: 2.0000 - binary_accuracy: 0.6119 - val_loss: 1.6891 - val_binary_accuracy: 0.5844
# Epoch 29/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9986 - binary_accuracy: 0.6183 - val_loss: 1.6885 - val_binary_accuracy: 0.5844
# Epoch 30/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9973 - binary_accuracy: 0.6205 - val_loss: 1.6878 - val_binary_accuracy: 0.5844
# Epoch 31/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9960 - binary_accuracy: 0.6205 - val_loss: 1.6872 - val_binary_accuracy: 0.5844
# Epoch 32/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9948 - binary_accuracy: 0.6226 - val_loss: 1.6866 - val_binary_accuracy: 0.5844
# Epoch 33/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9937 - binary_accuracy: 0.6226 - val_loss: 1.6859 - val_binary_accuracy: 0.5844
# Epoch 34/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9926 - binary_accuracy: 0.6247 - val_loss: 1.6853 - val_binary_accuracy: 0.5974
# Epoch 35/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9916 - binary_accuracy: 0.6247 - val_loss: 1.6847 - val_binary_accuracy: 0.5974
# Epoch 36/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9906 - binary_accuracy: 0.6290 - val_loss: 1.6841 - val_binary_accuracy: 0.5974
# Epoch 37/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9896 - binary_accuracy: 0.6290 - val_loss: 1.6835 - val_binary_accuracy: 0.5974
# Epoch 38/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9886 - binary_accuracy: 0.6290 - val_loss: 1.6830 - val_binary_accuracy: 0.5974
# Epoch 39/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9877 - binary_accuracy: 0.6269 - val_loss: 1.6824 - val_binary_accuracy: 0.5974
# Epoch 40/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9869 - binary_accuracy: 0.6269 - val_loss: 1.6818 - val_binary_accuracy: 0.5974
# Epoch 41/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9860 - binary_accuracy: 0.6269 - val_loss: 1.6813 - val_binary_accuracy: 0.5974
# Epoch 42/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9852 - binary_accuracy: 0.6269 - val_loss: 1.6808 - val_binary_accuracy: 0.5974
# Epoch 43/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9844 - binary_accuracy: 0.6269 - val_loss: 1.6803 - val_binary_accuracy: 0.5974
# Epoch 44/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9836 - binary_accuracy: 0.6290 - val_loss: 1.6798 - val_binary_accuracy: 0.5974
# Epoch 45/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9829 - binary_accuracy: 0.6290 - val_loss: 1.6794 - val_binary_accuracy: 0.5844
# Epoch 46/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9821 - binary_accuracy: 0.6333 - val_loss: 1.6790 - val_binary_accuracy: 0.5844
# Epoch 47/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9814 - binary_accuracy: 0.6375 - val_loss: 1.6785 - val_binary_accuracy: 0.5844
# Epoch 48/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9807 - binary_accuracy: 0.6375 - val_loss: 1.6782 - val_binary_accuracy: 0.5844
# Epoch 49/50
# 67/67 [==============================] - ETA: 0s - loss: 1.9637 - binary_accuracy: 0.6375 - val_loss: 1.6699 - val_binary_accuracy: 0.6494
# Epoch 50/50
# 67/67 [==============================] - ETA: 0s - loss: 1.6899 - binary_accuracy: 0.6738 - val_loss: 1.6695 - val_binary_accuracy: 0.6494
# 20/20 [==============================] - ETA: 0s
# [1.0107161998748779, 0.76428574323654175]

# %% [markdown]
# ### t(x) for labelling

# %%
#creating 100 random numbers
y_pred = y_pred_whole

f = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Jupyter/Keras/f_random.csv', 
                    delimiter = ',').reshape(100,1)
def t(x):
    return f.item (x)

def k (x):
    k = np.zeros ((98,7));
    i = 0;
    j = 0;
    for i in range (98):
        for j in range (7):
            if y_pred.item((i,j))<=t(x):
                np.put(k,[7*i+j],[1]);
    return k

g = np.zeros((98,1))
for x in range (100):
    m = np.sum(k(x), axis = 1).reshape(98,1);
    #print (m.shape)
    g = np.hstack((g,m));
g = np.delete(g,0,1)


i = 0
j = 0
m = np.zeros((98,100))
for i in range (98):
    min =100
    for j in range (100):
        if g.item ((i,j))<=min:
            min = g.item((i,j))
    for j in range (100):
        if g.item ((i,j))==min:
            np.put(m,[100*i+j],[1])
            
i = 0
j = 0
w = np.zeros((98,100))
for i in range (0,98):
    for j in range (0, 100):
        w_ = m.item((i,j))*t(j)
        np.put(w,[100*i+j],[w_])

        
cnt = np.count_nonzero(w, axis=1).reshape(98,1)
re_cnt = cnt[::-1]
w_total = np.sum(w, axis = 1).reshape(98,1)
w_avg = w_total/re_cnt
A = np.hstack([y_pred, np.ones((98,1))])
w1,w2,w3,w4,w5,w6,w7,b = np.linalg.lstsq(A,w_avg)[0]
print (w1,w2,w3,w4,w5,w6,w7,b)


def y_label (y_pred):
    
    I = y_pred.shape[0];
    J = y_pred.shape[1];
    
    x1_Y = y_pred [:,0].reshape(I,1);
    x2_Y = y_pred [:,1].reshape(I,1);
    x3_Y = y_pred [:,2].reshape(I,1);
    x4_Y = y_pred [:,3].reshape(I,1);
    x5_Y = y_pred [:,4].reshape(I,1);
    x6_Y = y_pred [:,5].reshape(I,1);
    x7_Y = y_pred [:,6].reshape(I,1);
    
    c_x = y_pred.reshape(I,J);
    y_thre = np.zeros((I,1));
    y_label = np.zeros((I,J));
    
    i = 0;
    j = 0;
    
    for i in range (I):
        x1 = x1_Y.item(i,0);
        x2 = x2_Y.item(i,0);
        x3 = x3_Y.item(i,0);
        x4 = x4_Y.item(i,0);
        x5 = x5_Y.item(i,0);
        x6 = x6_Y.item(i,0);
        x7 = x7_Y.item(i,0);
        y_tx = w1*x1+w2*x2+w3*x3+w4*x4+w5*x5+w6*x6+w7*x7+b;
        np.put (y_thre, [i], [y_tx]);
        
    for i in range (I):
        for j in range (J):
            threshold = y_thre.item(i,0);
            if c_x.item(i,j) >= threshold:
                np.put(y_label, [J*i+j], [1])
    
    return (y_label)


y_train_label = y_label(y_pred_train)
y_cv_label = y_label(y_pred_cv)
y_test_label = y_label(y_pred_test)
y_t_label = np.vstack((y_train_label,y_cv_label))
y_t = np.vstack((y_train,y_cv))

from sklearn.metrics import hamming_loss
from sklearn.metrics import coverage_error
print('hamming_loss_train',hamming_loss(y_train, y_train_label))
print('hamming_loss_cv',hamming_loss(y_cv, y_cv_label))
print('hamming_loss_test',hamming_loss(y_test, y_test_label))
print('hamming_loss_traindataset',hamming_loss(y_t, y_t_label))
# Out:
# [ 0.23649289] [-1.96888366] [ 2.61256284] [ 2.26501936] [-0.05244837] [ 0.20671851] [-1.28872121] [ 0.79331614]
# hamming_loss_train 0.4093816631130064
# hamming_loss_cv 0.3246753246753247
# hamming_loss_test 0.35714285714285715
# hamming_loss_traindataset 0.3974358974358974

# %%
#save model to json, weights to HDF5
model_json = model.to_json ()
with open ('model_app_adapt_cost_a.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('model_app_adapt_cost_a.h5')
print ('Saved model to disk')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8923eebc437b> in <module>()
#       1 #save model to json, weights to HDF5
# ----> 2 model_json = model.to_json ()
#       3 with open ('model_app_adapt_cost_a.json', 'w') as json_file:
#       4     json_file.write(model_json)
#       5 model.save_weights('model_app_adapt_cost_a.h5')
#
# NameError: name 'model' is not defined

# %%
#load json and create model
json_file = open('model_app_adapt_cost_a.json', 'r')
loaded_model_json = json_file.read ()
json_file.close ()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights('model_app_adapt_cost_a.h5')

# %%
x_whole = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_whole_scale.csv', 
                    delimiter = ',', usecols = (19,20,21,22), skip_header=1)
y_whole = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a_whole_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

loaded_model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])
print(loaded_model.evaluate (x_whole, y_whole, batch_size = 50))
y_pred_test = loaded_model.predict (x_whole)

x1 = y_pred_test [:,0].reshape(98,1);
x2 = y_pred_test [:,1].reshape(98,1);
x3 = y_pred_test [:,2].reshape(98,1);
x4 = y_pred_test [:,3].reshape(98,1);
x5 = y_pred_test [:,4].reshape(98,1);
x6 = y_pred_test [:,5].reshape(98,1);
x7 = y_pred_test [:,6].reshape(98,1);

i = 0;
label_cf = np.zeros((98,1));
for i in range (98):
    y_tx = -5.23*x1+3.7*x2+0.72*x3+0.92*x4-0.76*x5-3.63*x6+3.26*x7+2.7;
    np.put(label_cf, [i], [y_tx]);

i = 0;
j = 0;
cf = np.zeros((98,7))
for i in range (98):
    for j in range (7):
        cf_1 = y_pred_test.item((i,j))-label_cf.item((i,0));
        cf_2 = 10*cf_1;
        np.put(cf, [7*i+j], [cf_2]);
        
np.savetxt('APPadapt_cost_total.csv', cf, delimiter=',')
# Out:
# 98/98 [==============================] - ETA: 0s
# [1.5451267860373672, 0.69096211997830137]

# %%
x_test = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a1_cv_scale.csv', 
                    delimiter = ',', usecols = (19,20,21,22), skip_header=1)
y_test = np.genfromtxt ('C:/Users/z5023853/OneDrive - UNSW/Separated dataset_ML/a1_cv_scale.csv',
                      delimiter =',', usecols = (23,24,25,26,27,28,29),skip_header=1)

loaded_model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', 
               metrics=['binary_accuracy'])
print(loaded_model.evaluate (x_test, y_test, batch_size = 50))
y_pred_test = loaded_model.predict (x_test)

x1 = y_pred_test [:,0].reshape(14,1);
x2 = y_pred_test [:,1].reshape(14,1);
x3 = y_pred_test [:,2].reshape(14,1);
x4 = y_pred_test [:,3].reshape(14,1);
x5 = y_pred_test [:,4].reshape(14,1);
x6 = y_pred_test [:,5].reshape(14,1);
x7 = y_pred_test [:,6].reshape(14,1);

i = 0;
label_cf = np.zeros((14,1));
for i in range (14):
    y_tx = -5.23*x1+3.7*x2+0.72*x3+0.92*x4-0.76*x5-3.63*x6+3.26*x7+2.7;
    np.put(label_cf, [i], [y_tx]);

i = 0;
j = 0;
cf = np.zeros((14,7))
for i in range (14):
    for j in range (7):
        cf_1 = y_pred_test.item((i,j))-label_cf.item((i,0));
        cf_2 = 10*cf_1;
        np.put(cf, [7*i+j], [cf_2]);
        
np.savetxt('y_cost_APPadapt_cost.csv', cf, delimiter=',')
# Out:
# 14/14 [==============================] - ETA: 0s
# [137.947265625, 0.60204082727432251]
